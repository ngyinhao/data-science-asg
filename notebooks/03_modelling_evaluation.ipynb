# %% [markdown]
# # Seoul Bike Sharing Demand - 03 Modelling and Evaluation

# %% [markdown]
# Four required models are compared: Multiple Linear Regression, Decision Tree Regressor, Random Forest Regressor, and Gradient Boosting Regressor.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
comparison = pd.read_csv(PROJECT_ROOT / 'models' / 'model_comparison.csv')
comparison

# %% [markdown]
# ## Minimum 15 Comparison Points
#
# The comparison table includes MAE, RMSE, R2, adjusted R2, training score, testing score, train-test gap, cross-validation RMSE, residual mean, residual standard deviation, maximum absolute error, worst hour error, worst season error, worst holiday/functioning-day error, feature importance, interpretability, tuning complexity, deployment suitability, fit time, tuned parameters, and final rank.

# %% [markdown]
# ## Model Ranking
#
# ![Model RMSE comparison](../figures/08_model_rmse_comparison.png)

# %% [markdown]
# ## Actual vs Predicted
#
# ![Actual vs predicted](../figures/09_actual_vs_predicted.png)

# %% [markdown]
# ## Residual Distribution
#
# ![Residual distribution](../figures/10_residual_distribution.png)

# %% [markdown]
# ## Error by Hour and Season
#
# ![Error by hour](../figures/11_error_by_hour.png)
#
# ![Error by season](../figures/12_error_by_season.png)

# %% [markdown]
# ## Feature Importance
#
# ![Feature importance](../figures/13_feature_importance.png)

# %% [markdown]
# ## Final Model Choice
#
# The selected model is Random Forest Regressor because it produced the lowest test RMSE (177.20) with test R2 of 0.925.
